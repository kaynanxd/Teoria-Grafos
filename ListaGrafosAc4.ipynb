# %% [markdown]
# <a href="https://colab.research.google.com/github/kaynanxd/Teoria-Grafos/blob/main/ListaGrafosAc4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lista De grafos AC4 2026 - Kaynan Santos freitas - Ana Beatriz de oliveira duarte

# %% [markdown]
# ## Questao 1 ✅:
# Defina o que é:

# %% [markdown]
# #####A. O problema do caixeiro viajante em um grafo valorado positivamente, f-conexo e sem loops G(V,A)

# %% [markdown]
# #####B. O problema do caminho Hamiltoniano em um grafo valorado positivamente, conexo e sem loops G(V,E)

# %% [markdown]
# ##### C. O problema do carteiro chinês em um grafo valorado positivamente, f-conexo e sem loops G(V,E)

# %% [markdown]
# ##### D. As condições de existência de um caminho Euleriano em um grafo valorado positivamente, f- conexo e sem loops G(V,E)

# %% [markdown]
# ##### E. O problema de coloração de arestas

# %% [markdown]
# ##### F. O problema generalizado de coloração em vértices

# %% [markdown]
# ## Questao 2 ✅:
# Apresente um algoritmo em pseudo-código e rode um exemplo usando seu programa que trabalha
# com multigrafos, para responder os itens a seguir:

# %% [markdown]
# #### A. A coloração de um grafo randômico simples, conexo e sem loops G(V,E) com grau máximo 5 e 15 vértices;

# %% [markdown]
# #### B. O grafo acima é 4 colorível? Como você chegou a esta solução?

# %% [markdown]
# #### C. Qual a coloração completa de G(V,E) que você construiu?

# %% [markdown]
# #### D. Qual o número cromático de G(V,E)?

# %% [markdown]
# ## Questao 3 ✅:
# Apresente os algoritmos, implemente-os em sua aplicação de multigrafos e compare as soluções dos
# seguintes métodos: Vizinho Mais Próximo, Inserção Mais Distante e Método Exato (usando LI de
# Little et al)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Questao 4 ✅:
# Considere o grafo G(V,A) a seguir, apresente o método e use-o para encontrar o percurso ótimo do
# certeiro chinês neste grafo a partir de v0. Atribua custos positivos aos arcos de G(V,A) entre 10-20.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Questao 5 ✅:
# Para o grafo da Figura B, apresente uma k-coloração de G(V,E) e uma coloração de arestas de
# G(V,E), usando a sua implementação de grafos.

# %% [markdown]
# # Questao 6 ✅:
# Considerando as aplicações dos problemas estudados, explique:

# %% [markdown]
# ####A. Como poderia ser usado o PCV:
# a. na robótica móvel doméstica;
# b. para animação de jogos 3D;

# %% [markdown]
# ####B. Como poderia ser usado o PCC:
# a. na manutenção de redes de computadores;
# b. no patrulhamento policial e de trânsito;

# %% [markdown]
# ####C. Como poderia ser usado o problema da Coloração:
# a. no armazenamento de produtos químicos em prateleiras;
# b. na atribuição de frequências em antenas de aparelhos móveis.

# %% [markdown]
# # Questao 7 ✅:
# Explique a diferença entre o K-Caixeiro Viajante e o Min-Max Caixeiro Viajante. Apresente uma
# figura explicativa desta diferença sobre um grafo G(V,E) da figura B.

# %% [markdown]
# # Questao 8 ✅:
# Mostre em uma tabela, explique e apresente uma figura exemplo as versões do problema Caixeiro
# Viajante;

# %% [markdown]
# # Questao 9 ✅:
# Mostre em uma tabela, explique e apresente uma figura exemplo as versões do problema do Carteiro
# Chinês.

# %% [markdown]
# # Questao 10 ✅:
# Mostre em uma tabela, explique e apresente uma figura exemplo as versões do problema Coloração
# em arestas.

# %% [markdown]
# # Questao 11 ✅:
# Considere as complexidades das versões de cada problema não polinomial estudado. Faça uma tabela
# contendo o problema geral (PCV, PCC e Coloração), a versão, e a complexidade inerente à versão do
# problema.

# %% [markdown]
# # Questao 12 ✅:
# Considerando que um grafo simples, conexo e sem loops G(V,E) pode ser colorido nos vértices, e
# nas arestas, e que a coloração nas arestas é limitada ao mínimo no grau máximo e no máximo a este
# grau mais um, verifique e prove se é ou não possível encontrar uma k-coloração de vértices a partir
# da coloração de arestas de qualquer G(V,E) com as mesmas características.

# %% [markdown]
# # Questao 13 ✅:
# Um curso universitário tem 10 alunos de diferentes turmas que farão até 5 provas em salas distintas
# disponíveis em até dois horários, conforme as tabelas a seguir. Verifique se é possível que todos os
# alunos façam as provas sem perder nenhuma (Usar coloração).

# %% [markdown]
# ![image.png](data:image/png;base64,...)
